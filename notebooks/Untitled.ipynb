# %%
from llama_cpp import Llama
from transformers import LlamaForCausalLM, LlamaTokenizer, AutoTokenizer
import transformers
from langchain import HuggingFacePipeline
import torch

# %%
model = "meta-llama/Llama-2-7b-chat-hf"
model_dir = "/home/drifter/models/Llama-2-7b-chat-hf"

# %%
tokenizer = AutoTokenizer.from_pretrained(model_dir)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 tokenizer = AutoTokenizer.from_pretrained(model_dir)
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/models/auto/tokenization_auto.py:693, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     689     if tokenizer_class is None:
#     690         raise ValueError(
#     691             f"Tokenizer class {tokenizer_class_candidate} does not exist or is not currently imported."
#     692         )
# --> 693     return tokenizer_class.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#     695 # Otherwise we have to be creative.
#     696 # if model is an encoder decoder, the encoder tokenizer class is used by default
#     697 if isinstance(config, EncoderDecoderConfig):
#
# ...

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM

#tokenizer = AutoTokenizer.from_pretrained("/home/drifter/models/Llama-2-7b-chat-hf")
model = AutoModelForCausalLM.from_pretrained("/home/drifter/models/Llama-2-7b-chat-hf")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/transformers/utils/import_utils.py:1172, in _LazyModule._get_module(self, module_name)
#    1171 try:
# -> 1172     return importlib.import_module("." + module_name, self.__name__)
#    1173 except Exception as e:
#
# File ~/anaconda3/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1206, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1178, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1142, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'transformers.models.open_llama.configuration_open_llama'
#
# ...

# %%
import transformers

model = transformers.AutoModelForCausalLM.from_pretrained("/home/drifter/models/Llama-2-7b-chat-hf")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/transformers/utils/import_utils.py:1172, in _LazyModule._get_module(self, module_name)
#    1171 try:
# -> 1172     return importlib.import_module("." + module_name, self.__name__)
#    1173 except Exception as e:
#
# File ~/anaconda3/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1206, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1178, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1142, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'transformers.models.open_llama.configuration_open_llama'
#
# ...
